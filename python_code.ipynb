# %% [markdown]
# <a href="https://colab.research.google.com/github/mayankjoshi1992/Basic-Python-Code/blob/main/python_code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name = "Mayank Joshi"

# %%
age = 32
height = 5.6
print(type(age))
print(type("height"))
# Out:
# <class 'int'>
# <class 'str'>

# %%
price = "250"
new_price = int(price)
print(new_price)
# Out:
# 250

# %%
language = "Python"
print(language[0])
# Out:
# P

# %%
text = "I am learning Python"
text.replace("Python","SQL")
# Out:
# 'I am learning SQL'

# %%
tools = ["Python", "SQL", "Linux", "AWS"]
print(tools)
# Out:
# ['Python', 'SQL', 'Linux', 'AWS']

# %%
tools[1]
# Out:
# 'SQL'

# %%
tools = ["Python", "SQL"]
tools.append("Docker")
print(tools)
# Out:
# ['Python', 'SQL', 'Docker']

# %%
tup = ("mayank",[1,2,3,4], "Akash")
print(tup[1][2])
# Out:
# 3

# %%
a = 1,2,3,4
print(a)
# Out:
# (1, 2, 3, 4)

# %%
servers = ("server1", "server2", "server3")
new_server = list(servers)
print(new_server)
# Out:
# ['server1', 'server2', 'server3']

# %%
ids = [101, 102, 101, 103, 102, 104]
new_id = set(ids)
print(new_id)
# Out:
# {104, 101, 102, 103}

# %%
a = {1, 2, 3, 4}
b = {3, 4, 5, 6}
print(a.intersection(b))
# Out:
# {3, 4}

# %%
c = {1, 2, 3, 4}
d = {3, 4, 5, 6}
print(c & d)
# Out:
# {3, 4}

# %%
a = {1, 2, 3, 4}
b = {3, 4, 5, 6}
c = a.union(b)
print(c)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
my_dict = {
    "name" : "Mayank",
    "role" : "Data Engineer",
    "experience" : 4
}
print(my_dict)
# Out:
# {'name': 'Mayank', 'role': 'Data Engineer', 'experience': 4}

# %%
employee = {
    "name": "Mayank",
    "role": "Data Engineer",
    "experience": 4
}
print(employee["role"])
# Out:
# Data Engineer

# %%
employee = {
    "name": "Mayank",
    "role": "Data Engineer",
    "experience": 4
}
employee["experience"] = 5
print(employee)
# Out:
# {'name': 'Mayank', 'role': 'Data Engineer', 'experience': 5}

# %%
employee = {
    "name": "Mayank",
    "role": "Data Engineer",
    "experience": 5
}
employee["city"] = "Ralegh"
print(employee)
# Out:
# {'name': 'Mayank', 'role': 'Data Engineer', 'experience': 5, 'city': 'Ralegh'}

# %%
employee["salary"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_755/5014623.py in <cell line: 0>()
# ----> 1 employee["salary"]
#
# KeyError: 'salary'

# %%
print(employee.get("salary"))
# Out:
# None

# %%
text = "Python Data Engineering"

print(text[0:6])
# Out:
# Python

# %%
text = "Python"

print(text[::-1])
# Out:
# nohtyP

# %%
data = "Python,SQL,Linux,AWS"
new_data = list(data)
print(new_data)
# Out:
# ['P', 'y', 't', 'h', 'o', 'n', ',', 'S', 'Q', 'L', ',', 'L', 'i', 'n', 'u', 'x', ',', 'A', 'W', 'S']
